# %%
# 1 loading and studying the data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('https://raw.githubusercontent.com/Tirth678/Data-Analysis-Projects/refs/heads/main/Wine%20Quality%20Dataset%20(1).csv')

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
data.shape
# Out:
# (4898, 12)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4898, step=1)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4898, step=1)

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
# viewing the distributions of various features of database in data set and calculating central tendancies
plt.figure(figsize = (9,4))

sns.histplot(data = data ,x = 'fixed acidity', color = 'orange',
             edgecolor = 'linen', alpha = 0.7, bins = 5)

plt.title("Histogram of Fixed Acidity")
plt.xlabel('Fixed Acidity')
plt.ylabel('Count')
plt.show()

# %%
round(data['fixed acidity'].mean(),2)
# Out:
# 6.8

# %%
round(data['fixed acidity'].median(),2)
# Out:
# 6.8

# %%
round(data['fixed acidity'].skew(),2)
# Out:
# 0.65

# %%
plt.figure(figsize = (9,4))

sns.histplot(data = data ,x = 'fixed acidity', color = 'orange',
             edgecolor = 'linen', alpha = 0.5, bins = 5)

plt.title("Histogram of Fixed Acidity")
plt.xlabel('Fixed Acidity')
plt.ylabel('Count')
plt.vlines(data['fixed acidity'].mean(), ymin = 0, ymax = 4000, colors='blue', label='Mean')
plt.vlines(data['fixed acidity'].median(), ymin = 0, ymax = 4000, colors='red', label='Median')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (9,4))

sns.histplot(data = data ,x = 'volatile acidity', color = 'green',
             edgecolor = 'linen', alpha = 0.7, bins = 5)

plt.title("Histogram of Volatile Acidity")
plt.xlabel('Volatile Acidity')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize = (9,4))

sns.distplot(data['volatile acidity'], color = 'teal')

plt.title("Distplot of Volatile Acidity")
plt.xlabel('Volatile Acidity')
plt.ylabel('Density')
plt.show()
# Out:
# /var/folders/s3/cvr5v5fn2lj0g39xwwzgpx_m0000gn/T/ipykernel_6216/1080840471.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['volatile acidity'], color = 'teal')

# %%
round(data['volatile acidity'].mean(),2)
# Out:
# 0.28

# %%
round(data['volatile acidity'].median(),2)
# Out:
# 0.26

# %%
round(data['volatile acidity'].skew(),2)
# Out:
# 1.58

# %%
round(data['volatile acidity'].mode(), 2)
# Out:
# 0    0.28
# Name: volatile acidity, dtype: float64

# %%
plt.figure(figsize = (9,4))

sns.histplot(data = data ,x = 'volatile acidity', color = 'green',
             edgecolor = 'linen', alpha = 0.5, bins = 5)

plt.title("Histogram of Volatile Acidity")
plt.xlabel('Volatile Acidity')
plt.ylabel('Density')
plt.vlines(data['volatile acidity'].mean(), ymin = 0, ymax = 4000, colors='blue', label='Mean')
plt.vlines(data['volatile acidity'].median(), ymin = 0, ymax = 4000, colors='red', label='Median')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (9,4))

sns.histplot(data = data ,x = 'citric acid', color = 'pink',
             edgecolor = 'linen', alpha = 0.5, bins = 5)

plt.title("Histogram of Citric Acidity")
plt.xlabel('Citric Acidity')
plt.ylabel('Count')
plt.show()

# %%
round(data['citric acid'].mean(),2)
# Out:
# 0.33

# %%
round(data['citric acid'].median(),2)
# Out:
# 0.32

# %%
round(data['citric acid'].mode(),2)
# Out:
# 0    0.3
# Name: citric acid, dtype: float64

# %%
round(data['citric acid'].skew(),2)
# Out:
# 1.28

# %%
plt.figure(figsize = (9,4))

sns.histplot(data = data ,x = 'citric acid', color = 'pink',
             edgecolor = 'linen', alpha = 0.5, bins = 5)

plt.title("Histogram of Citric Acidity")
plt.xlabel('Citric Acidity')
plt.ylabel('Count')
plt.vlines(data['citric acid'].mean(), ymin = 0, ymax = 4000, colors='blue', label='Mean')
plt.vlines(data['citric acid'].median(), ymin = 0, ymax = 4000, colors='red', label='Median')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (11,6))

sns.distplot(data['citric acid'], color = 'green')

plt.title("Distplot of Citric Acid")
plt.xlabel('Citric Acid')
plt.ylabel('Density')
plt.show()
# Out:
# /var/folders/s3/cvr5v5fn2lj0g39xwwzgpx_m0000gn/T/ipykernel_6216/3866228207.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['citric acid'], color = 'green')

# %%
quality = pd.DataFrame(data['quality'].value_counts())

# %%
quality.index
# Out:
# Index([6, 5, 7, 8, 4, 3, 9], dtype='int64', name='quality')

# %%
round(data['quality'].mode(),2)
# Out:
# 0    6
# Name: quality, dtype: int64

# %%
data['quality'].value_counts()
# Out:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64

# %%
rep_acid = pd.DataFrame(index = ['fixed acidity','volatile acidity','citric acid','quality'],
                     data = [data['fixed acidity'].mean(),data['volatile acidity'].mean(),
                             data['citric acid'].mean(),data['quality'].value_counts().index[0]])

# %%
rep_acid
# Out:
#                          0
# fixed acidity     6.854788
# volatile acidity  0.278241
# citric acid       0.334192
# quality           6.000000
