# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('https://raw.githubusercontent.com/Tirth678/Data-Analysis-Projects/refs/heads/main/Project%202/Data/Employee%20Dataset%20(1).csv')

# %%
# getting information about the data
data.head()
# Out:
#    id groups  age  healthy_eating  active_lifestyle  salary
# 0   0      A   36               5                 5    2297
# 1   1      A   26               3                 5    1134
# 2   2      A   61               8                 1    4969
# 3   3      O   24               3                 6     902
# 4   4      O   39               6                 2    3574

# %%
data.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
data.columns
# Out:
# Index(['id', 'groups', 'age', 'healthy_eating', 'active_lifestyle', 'salary'], dtype='object')

# %%
data.shape
# Out:
# (50, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                50 non-null     int64
#  1   groups            50 non-null     object
#  2   age               50 non-null     int64
#  3   healthy_eating    50 non-null     int64
#  4   active_lifestyle  50 non-null     int64
#  5   salary            50 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 2.5+ KB

# %%
plt.figure(figsize=(9,4))

sns.scatterplot(data = data, x = 'age', y = 'salary', color = 'teal', edgecolor = 'linen', alpha = 0.5)

plt.title("Scatterplot of Employee Age v/s Employee Salary")
plt.xlabel('Employee Age')
plt.ylabel('Employee Salary')
plt.show()

# %%
plt.figure(figsize = (9,4))
sns.scatterplot(data = data, x = 'healthy_eating', y = 'active_lifestyle', color = 'red', edgecolor = 'linen', alpha = 0.5)

plt.title('Scatterplot of Healthy eating v/s Active lifestyle')
plt.xlabel('Healthy eating')
plt.ylabel('Active lifestyle')
plt.show()

# %%
plt.figure(figsize = (9,4))
sns.scatterplot(data = data, x = 'healthy_eating', y = 'salary', edgecolor = 'linen', color = 'black', alpha = 0.5)

plt.title('Scatterplot of Healthy Eating v/s Salary')
plt.xlabel('Healthy Eating')
plt.ylabel('Salary')
plt.show()

# %%
plt.figure(figsize = (9,4))
sns.countplot(data = data, x = 'groups', edgecolor = 'linen', color='red', alpha = 0.5)

plt.title('Count Plot of Groups')
plt.xlabel('Groups')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize = (9,4))
sns.histplot(data = data, x = 'salary', color = 'purple', edgecolor = 'linen', alpha = 0.5, bins = 10)

plt.title('Histroplot of Salary')
plt.xlabel('Salary')
plt.ylabel('Count')
plt.show()

# %%
sub1 = data[data['healthy_eating'] > 8]
sub1
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 26  26      A   62               9                 6     700

# %%
sub2 = data[data['salary'] < 1000]
sub2
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 3    3      O   24               3                 6     902
# 15  15      B   26               3                 8     662
# 18  18      A   27               2                 6     779
# 26  26      A   62               9                 6     700
# 32  32      A   22               3                 8     662
# 35  35      O   27               2                 4     785
# 38  38     AB   26               3                 7     670
# 39  39      B   29               2                 6     779
# 43  43      O   23               4                10     556

# %%
sub = data[(data['healthy_eating']>8) & (data['salary']<1000)]

# %%
sub
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 26  26      A   62               9                 6     700
